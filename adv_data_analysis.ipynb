# %%
import cudf as pd
from scripts.basic_stats import parse_directory

# %%
d_irectory = 'data/adv_data_separated'

# %%
parse_directory(d_irectory)
# Out:
# --------------------------------------
# Результаты для рекламной кампании yandex_organic:
# Суммы касаний кликов, показов и конверсий
# Клики: 440532
# Показы: 1762892
# Конверсии: 96629
# Сумма показов без конверсий : 2203424
# Процент конверсий от общего числа касаний : 4.201
# Общая стоимость рекламной кампании для yandex_organic : 54287666.1195
# Средняя стоимость кампании на 1 пользователя : 510.16
# --------------------------------------
#
#
# --------------------------------------
# Результаты для рекламной кампании yahoo_organic:
# Суммы касаний кликов, показов и конверсий
# Клики: 19383
# Показы: 76492
# Конверсии: 4275
# Сумма показов без конверсий : 95875
# Процент конверсий от общего числа касаний : 4.269
# Общая стоимость рекламной кампании для yahoo_organic : 2488059.1788000003
# Средняя стоимость кампании на 1 пользователя : 523.912
# --------------------------------------
#
#
# --------------------------------------
# Результаты для рекламной кампании regular_email:
# ...
