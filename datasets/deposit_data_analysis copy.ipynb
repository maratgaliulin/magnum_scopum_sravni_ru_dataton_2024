# %%
import cudf as pd
import cupy as cp
import numpy as np
# import matplotlib.pyplot as plt
# import pandas

# %%
# Загружаю датасет по депозитам

deposit_data = pd.read_csv('data/deposit_data.csv', index_col=0)

# %%
deposit_data = deposit_data.reset_index().drop('index', axis=1)

# %%
deposit_data.head()unioun all
# Out:
#                             user_id campaign_type     source_medium  \
# 0  70391e123115e9d0f463495adfa9ff91          show  yandex / organic
# 1  70391e123115e9d0f463495adfa9ff91         click  yandex / organic
# 2  6f886cae30e6160b0bb1f407f1b3e888          show      yandex / cpc
# 3  d74e70ad7b9007f7a25910d01009055c          show  ios / mobile_app
# 4  567628d484442d4f42fae9b76e5bb5cf          show       ya.ru / cpc
#
#                utm_campaign interface  campaign_cost   user_phone  \
# 0  client_rebrand_megamaket       app            0.0  79143423444
# 1             bk_adv_client       web            0.0  79143423444
# 2       retarget_case_title       app            0.0  79143152479
# 3    adv_operator_brandkeys       app            0.0  79183973165
# 4      client_title_rebrand       api            0.0  79133318417
#
#                                                   id event_type event_status  \
# 0  aa154add98285bd92c7bbe42f602ef7218a45b3d7ce0bf...       show         <NA>
# 1  416ce92d431422cffd83519bbdddebba9f92718b21e9d9...      click         <NA>
# 2  ef3b80ba8ee67b50530d45e0081035ddbad7b8bc392361...       show         <NA>
# 3  002e390fcadd76fdd51bd280311abc2f2eae58e3e2a768...       show         <NA>
# 4  b7f5b27f44a5e024737f3a541f2fa02be1f1da1133ab75...       show         <NA>
#
#    payout product_type     time_from_reg_till_event  \
# 0     0.0     deposits  152 days 03:39:49.120132000
# 1     0.0     deposits  152 days 03:39:49.120132000
# 2     0.0     deposits  201 days 10:07:20.386032000
# 3     0.0     deposits  193 days 14:15:50.642060000
# 4     0.0     deposits  211 days 13:11:24.264851000
#
#   time_from_camp_start_till_event
# 0      92 days 16:47:29.443329000
# 1      82 days 19:27:19.982213000
# 2     134 days 22:36:33.788781000
# 3       2 days 22:40:46.960830000
# 4      82 days 12:27:15.366014000

# %%
# Сохраняю названия столбцов в виде numpy-массива

cols = np.array(deposit_data.columns)

# %%
# Удаляю из массива столбцов ненужные

cols = np.delete(cols, [0,5,6,7,10,11,12,13])

# %%
# Применяю метод value_counts() к каждому столбцу из массива

for col in cols:
    print(col)
    print('-------------------------')
    print(deposit_data[col].value_counts())
    print('::::::::::::::::::::::::::')
    print('\n')

# %%
# Создаю подмассив с ID пользователей и разделенными значениями из столбца campaign_type

deposit_data_by_campaign_type = pd.get_dummies(deposit_data[['user_id', 'campaign_type']], columns=['campaign_type'], dtype='int')

# %%
# Группирую значения в массиве по ID пользователя. Таким образом в каждом столбце для каждого пользователя суммируется кол-во каждого из трех типов касаний 

deposit_data_by_campaign_type = deposit_data_by_campaign_type.groupby('user_id').sum()

# %%
# Выделяю пользователей, у которых была хотя бы одна конверсия

deposit_data_by_campaign_type_conversions = deposit_data_by_campaign_type.loc[deposit_data_by_campaign_type['campaign_type_conversion'] > 0]

# %%
# Сортирую этих пользователей по количеству конверсий

deposit_data_by_campaign_type_conversions.sort_values(by='campaign_type_conversion', ascending=False).head(50)
# Out:
#                                   campaign_type_click  \
# user_id
# 067c102c89732a569567d2f673dbf0c9                    2
# 558fa53918641cdaec9c564da667d2f0                    1
# 8e7e0913bd4ad9c5b0501ad8c8dfe64b                    1
# 8b436194ccd8675e7c6a0cb8076aeadc                    1
# 14bd689a3dcbda5e6db725ac450ac3b0                    1
# d45f2b7ba3165c17ef3f1384f5fe7544                    1
# 433b959f045da1c479310a89553061b2                    1
# 81a0fb764b07daf6005cbdb368f84231                    1
# cf76be347b9f9c012684552705d5bc88                    1
# c3d7c0bafa2ca7effeb3b65067989bbd                    1
# c822d0617abfb7c15b626674d7a65a57                    1
# c35050864991e5be15df8d8c537e9018                    1
# 8550a41778579948868dae5943d8179f                    1
# 583cc35f119e576bb1b836a3b11001c9                    1
# bc6edd72b6244281b815b1b37028ca09                    1
# 14f5049469793cc7c6fdfdce484678f1                    1
# 53ecf67ea28b2595c9393e9160f86f11                    1
# 856d24beaa993f31def1f7d7bb205d95                    1
# 83f4037e6cd352974e2cd56060ecd2fa                    1
# fb9a00063d10bb979fe593199c4108a2                    1
# e02a93d032fc3306109b6cb984df5ea1                    1
# 2bb04e748c1566c4fdbdfda429bbfc02                    1
# b1fe34ad70bad40d5d78597508eb2f92                    1
# ada08f13cc0ea3fcece84323e876740d                    1
# 43a00a02ed51ebb05aac20b8c5e58a21                    1
# 0bb4ddf4c667e66f7adfa8277c3de0d5                    1
# 0bbae1b999e5ac42d9caa3350186f3fe                    1
# e36365135e9ccbc9cdf26b00331404a7                    1
# 074f1611861a832a3fe31325df418139                    1
# 3e06e7e8243d834f6448c368a7900a61                    1
# 63d0e937bacd670536c95db2b664e168                    1
# 67da7ad7c5fbef3da54b7dca9252dd05                    1
# b709aecdcbbb9e7b142a78db2bf67fec                    1
# cc56302ad71e6a6ffbc74b24a376abe8                    1
# 6041770964e91595677fccaa063bf000                    1
# 1487123000e52d780d263852156b5fd8                    1
# 4c69adf0589e54316f39497b35312b29                    1
# 083246cd80d87c04ed5fa9e41445b1b9                    1
# 79142bf6086162e126e0c2d4f6358320                    1
# a7957251f8c267290890881309fee60c                    1
# 9657b694706d9087006377b943f5301f                    1
# e692ca88aa7c632fc275bed399b51739                    1
# 927bfeb2384c269504e195111ea275f2                    1
# f170046612269f694662d3402fbbaf00                    1
# 4c298081896b17a40afc9a243dd701a0                    1
# 50ef2ffcfd4171203a2c4c29db916e93                    1
# 205eb7c1f97d1773563352d4378a213b                    1
# c5940fb9ff5a7c0986edb102e63606cf                    1
# 5a6ebdb440e383148c2189e53546c441                    1
# 41c9e7e6603629d5cec8601ab48b9ca9                    1
#
#                                   campaign_type_conversion  campaign_type_show
# user_id
# 067c102c89732a569567d2f673dbf0c9                        15                   2
# 558fa53918641cdaec9c564da667d2f0                        12                   1
# 8e7e0913bd4ad9c5b0501ad8c8dfe64b                        12                   1
# 8b436194ccd8675e7c6a0cb8076aeadc                        12                   2
# 14bd689a3dcbda5e6db725ac450ac3b0                        12                   1
# d45f2b7ba3165c17ef3f1384f5fe7544                        12                   1
# 433b959f045da1c479310a89553061b2                        12                   1
# 81a0fb764b07daf6005cbdb368f84231                        12                   1
# cf76be347b9f9c012684552705d5bc88                        12                   1
# c3d7c0bafa2ca7effeb3b65067989bbd                        12                   1
# c822d0617abfb7c15b626674d7a65a57                        12                   1
# c35050864991e5be15df8d8c537e9018                        12                   1
# 8550a41778579948868dae5943d8179f                        12                   1
# 583cc35f119e576bb1b836a3b11001c9                        12                   1
# bc6edd72b6244281b815b1b37028ca09                        12                   2
# 14f5049469793cc7c6fdfdce484678f1                        12                   1
# 53ecf67ea28b2595c9393e9160f86f11                        12                   1
# 856d24beaa993f31def1f7d7bb205d95                        12                   1
# 83f4037e6cd352974e2cd56060ecd2fa                        12                   1
# fb9a00063d10bb979fe593199c4108a2                        12                   1
# e02a93d032fc3306109b6cb984df5ea1                        12                   2
# 2bb04e748c1566c4fdbdfda429bbfc02                        12                   1
# b1fe34ad70bad40d5d78597508eb2f92                        12                   1
# ada08f13cc0ea3fcece84323e876740d                         9                   1
# 43a00a02ed51ebb05aac20b8c5e58a21                         9                   2
# 0bb4ddf4c667e66f7adfa8277c3de0d5                         9                   1
# 0bbae1b999e5ac42d9caa3350186f3fe                         9                   1
# e36365135e9ccbc9cdf26b00331404a7                         9                   1
# 074f1611861a832a3fe31325df418139                         9                   1
# 3e06e7e8243d834f6448c368a7900a61                         9                   1
# 63d0e937bacd670536c95db2b664e168                         9                   1
# 67da7ad7c5fbef3da54b7dca9252dd05                         9                   1
# b709aecdcbbb9e7b142a78db2bf67fec                         9                   1
# cc56302ad71e6a6ffbc74b24a376abe8                         9                   1
# 6041770964e91595677fccaa063bf000                         9                   1
# 1487123000e52d780d263852156b5fd8                         9                   1
# 4c69adf0589e54316f39497b35312b29                         9                   1
# 083246cd80d87c04ed5fa9e41445b1b9                         9                   1
# 79142bf6086162e126e0c2d4f6358320                         9                   1
# a7957251f8c267290890881309fee60c                         9                   1
# 9657b694706d9087006377b943f5301f                         9                   1
# e692ca88aa7c632fc275bed399b51739                         9                   1
# 927bfeb2384c269504e195111ea275f2                         9                   1
# f170046612269f694662d3402fbbaf00                         9                   1
# 4c298081896b17a40afc9a243dd701a0                         9                   1
# 50ef2ffcfd4171203a2c4c29db916e93                         9                   1
# 205eb7c1f97d1773563352d4378a213b                         9                   1
# c5940fb9ff5a7c0986edb102e63606cf                         9                   1
# 5a6ebdb440e383148c2189e53546c441                         9                   1
# 41c9e7e6603629d5cec8601ab48b9ca9                         9                   1
